# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib notebook
df = pd.DataFrame.from_dict(dict(x=np.random.rand(1200)))
df.plot();
# Out:
# <img src="data:image/png;base64,...">

# %%
import odo

# %%
# !pip uninstall psycopg2
# Out:
# Uninstalling psycopg2-2.6.1:
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2-2.6.1-py3.4.egg-info
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__init__.py
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/__init__.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/_json.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/_range.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/errorcodes.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/extensions.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/extras.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/pool.cpython-34.pyc
#   /usr/local/anaconda/lib/python3.4/site-packages/psycopg2/__pycache__/psycopg1.cpython-34.pyc
# ...

# %%
# odo.odo(df, 'postgresql://localhost::aaaa')
odo.odo('../../osqf2015/data/db.bcolz/', 'postgresql://localhost::risk_factors')
# Out:
# Table('risk_factors', MetaData(bind=Engine(postgresql://localhost)), Column('Open', Float(precision=53), table=<risk_factors>, nullable=False), Column('High', Float(precision=53), table=<risk_factors>, nullable=False), Column('Low', Float(precision=53), table=<risk_factors>, nullable=False), Column('Close', Float(precision=53), table=<risk_factors>, nullable=False), Column('Volume', Float(precision=53), table=<risk_factors>, nullable=False), Column('Dividend', Float(precision=53), table=<risk_factors>, nullable=False), Column('Split', Float(precision=53), table=<risk_factors>, nullable=False), Column('Adj_Open', Float(precision=53), table=<risk_factors>, nullable=False), Column('Adj_High', Float(precision=53), table=<risk_factors>, nullable=False), Column('Adj_Low', Float(precision=53), table=<risk_factors>, nullable=False), Column('Adj_Close', Float(precision=53), table=<risk_factors>, nullable=False), Column('Adj_Volume', Float(precision=53), table=<risk_factors>, nullable=False), 
# ...
